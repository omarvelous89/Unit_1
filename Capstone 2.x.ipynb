# %% [markdown]
# # Research Proposal
#
#
# # Analysis
#
# ## Motivation for this study
#
# In the past few years the anti-vaccine movement became national news and their views became well-known. The language they used framed the issue as the government violating the right of the individual to choose what medical treatment they or their family can obtain. This movement found its justification in medical papers that found correlations between vaccines and Autism. These papers found that the links between Autism and Vaccines were significant and traced the cause to a preservative in the vaccines called Thiomersal, which contains Mercury as part of its molecular structure.
#
# Families found themselves armed with a practical scapegoat in Mercury, a known poisonous substance, and a small group of medical professionals who could back them up. People began acting on these beliefs and obtained exemptions to vaccinations for their children. These exemptions were Personal Belief Exemptions and could be found across the country. The purpose of the exemptions was to accommodate those whose religious beliefs forbade them from receiving certain vaccines. It wasn't seen as a threat to public health because it was assumed that the amount of people seeking these exemptions would be so low that the public health cost of offering the Exemption was minimal.
#
# However, if the number of people within a population seeking exemptions gets too large, then the immunity of the population, or herd, becomes compromised. Unvaccinated people are more likely to become a disease vector because their immune system is less likely to overcome an infection it hasn't encountered before. The unvaccinated person who becomes exposed, will incubate the bacteria and may become sick. If the virus or bacteria mutates inside the host, they can infect other people with the new strain. This is problematic because mutations can make vaccines less effective.  Herd immunity relies on the fact that if enough people are vaccinated, disease outbreaks are prevented because infection a chain of infections is less likely to occur.
#
# ## Questions
# * Has Herd Immunity been compromised in California?
# * Are Private schools more culpable for higher rates of exemption, i.e. lower rates of vaccination.
# * Does the economic class of the child affect exemption rates?
# * Do Medical Exemptions or Personal Belief Exemptions contribute more to the exemption rates in California?
#
# ## Hypothesis
#
# * Null Hypothesis: vaccination rates will remain stable during the length of the study
# * H1. We will see vaccination rates that are below threshold immunity.
#
#
# * Null Hypothesis: Private schools will not show a higher rate of Personal Belief Exemptions than Public Schools
# * H1. Private school will show a higher rate of Personal Belief Exemptions than Public schools.
#
#
# * Null Hypothesis: There will be no difference in exemption rates based on economic status.
# * H1. Economic class is a factor and families with higher incomes will also show a higher rate of non-vaccination.
#
#
# ## Variables
#
# ### Independent variables
# The data conatins several labels that serve as our Independant variables. These are County, School Name, School Code, and School Type. Of these variables School name is problematic because there are inconsistent spellings throughout the data. To avoid any confusion in our experiment any selection on the data will be done using the School Code
#
# ### Dependent Variable
# Vaccination rate is my key metric. It is the measurable human behavior I evaluate my hypothesis by. My hypothesis states that the vaccination rate is dependent on school type, economic status, and the concept of herd immunity.
#
# Two other dependent variables are the Medical exemptions and the Personal Belief Exemptions. The raw counts for these variables are provided per school. The rates are calculated from the raw counts provided in the data divided by the class size.
#
# These are good key metrics because they are also directly related. The overall vaccination rate and exemption rates should "complete" each other. They are approaching the questions from two different angles, Those who do vaccinate and those who do not
#
# Other Dependent variables in the data are the Columns for class size, nMMr, nDTP, and nPolio. Class size is self explanatory but the other three measure the number of vaccinated students in the class.
#
#
# ### Confounding variables
# grade level is is a confounding variable due to the Law. Laws are also not static. If there has been a change in the laws then there will almost certainly be a noticeable difference in the data. The point is that while this is a limitation of my control and the experiment as a whole, it's only a part of a larger analysis which accepts this limitation and works around it. However, for this study grade level is constant since the data is only for Kindergarten aged students and we're running a between-subject experiment.
#
# Other confounding variables are the timing of the data being collected. Sometimes students may be un-vaccinated due to immigration status, or issues with their medical insurance but they present proof to the school of their intent to vaccinate. However, the school will report that the student is unvaccinated. We assume that these events are uncommon since vaccines are widely available and should be covered either by the State or 3rd party insurance.Additionally the chances that a child is missing a dose of a certain vaccine is assumed to be negligble.
#
#
# ## Our Participants
# The participants in this study, or the population under analysis, is Kindergarten aged Californian students. The information was gathered by the schools the children attended and aggregated by the Counties/State. The students are only observed once per year. The data from each year represents a new population of the same school aged children.(Thus this is a between-subject design.
#
# ### Control Groups / A-B Groups
#
# We do not have a control group in this experiment but we do have the CDC reccomendations for vaccination levels. These vaccination levels do not depend on any of the independent variables I have but rather on a formula, $1-(1/R_0)$.
#
# $R_0$ is called the *Reproductive Number*. It is calculated empirically and is unique to every infectious agent. $R_0$ measures the amount of infected cases that can arise from another infection. For most diseases like Measles (found in the MMR vaccine), $R_0 = 12$. Ideally for a distribution of vaccine rates, one would expect to see very low distributions everywhere except around 95%-100%. In the histograms above, the final bin represents the 95%-100% range.
#
# To test Additionally We will also be comparing different schools to each other, as well as counties and school Types. Consequently we will make use of A/B testing to compare different groups to each other internally
#
#
# # Limitations of the Study
#
# According to Mackenzie (p.167) "control variables compromise external validity by limiting responses to specific situations and people." This is true for this experiment as well. This experiment would only validates my findings for a very specific age/grade level, i.e. it isn't generalizeable to the population of California.
#
# However as we noted above, any sort of analysis across a less specific group (say including all grades k-12) would run the risk of Simpson's paradox. If I were presented with the k-12 data, I would still end up splitting the data into groups based on age because the law defines hard limits that should adhered to.

# %% [markdown]
# ### H1 We will see increased rates of non-vaccination that are below threshold immunity.
# To test hypothesis 1 we will make use of histograms. The histogram bins will represent the vaccination rate present in the classes. There will be three histograms, one for each vaccine cocktail that we have data for, MMR( Measles/Mups/Rubella), DTP (Diptheria/Tetanus/Pertussis) and Polio.
#
# The second test of this hypothesis will come from tracking the vaccination rate per year per vaccine. While the histograms show us data that has been summed over all the years we have available, seeing the vaccination levels fluctuate through time will give us a better sense of any trends in the data.
#
# Our data only contains raw counts per vaccine, per class. However the data also provides us with the class size so the first step before making the histograms is calculating the vaccination rates by dividing the number of vaccinations in the class by the class size.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats 

SD = pd.read_csv('SD.csv')
SD['MMR_rate'] = SD.nMMR / SD.n
SD['DTP_rate'] = SD.nDTP / SD.n
SD['Polio_rate'] = SD.nPolio/ SD.n
SD['PBE_rate'] = SD.nPBE/SD.n
SD['PME_rate'] = SD.nPME/SD.n #Added 5 new columns to my dataframe. rate of vaccination per row.


err = SD.loc[lambda df:SD['year'] == 0]
er = SD.loc[lambda df:SD['year'] == 1]
SD = SD.drop([SD.index[3250], SD.index[27082]])
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
plt.figure(figsize=(13,8))

ax1 = plt.subplot(311)
sns.lineplot(x="year", y="MMR_rate", hue="schoolType", style="schoolType", data=SD)
plt.ylabel('MMR rate', Fontsize=14);
plt.xlim(2000,2014);
plt.ylim(0.8,1.0);

ax2 = plt.subplot(312)
sns.lineplot(x="year", y="DTP_rate", hue="schoolType", style="schoolType", data=SD)
plt.ylabel('DTP rate', Fontsize=14);
plt.xlabel('Year', Fontsize=14);
plt.xlim(2000,2014);
plt.ylim(0.8,1.0);

ax3 = plt.subplot(313)
sns.lineplot(x="year", y="Polio_rate", hue="schoolType", style="schoolType", data=SD)
plt.ylabel('Polio rate', Fontsize=14);
plt.xlabel('Year', Fontsize=14);
plt.xlim(2000,2014);
plt.ylim(0.8,1.0);

priv = SD.loc[lambda df:SD['schoolType'] == 'PRIVATE'] #new dataframe with only private schools
pub = SD.loc[lambda df:SD['schoolType'] == 'PUBLIC'] #new dataframe with only public schools

# %% [markdown]
# ### Statistical testing
#
# For this t-test, see results below, the two groups are Public schools and Private schools. Each t-test will compare one of the vaccine cocktails between the two groups.
#
# The line graphs that track the vaccination rates over time add more detail to the general information we glean from the histograms below. As stated earlier the 95% value recommended by the CDC and WHO isn't being met for any vaccine, irrespective of school type. Private schools are more culpable in that when data begins, they are already reporting vaccination levels below 95% and exhibit a downward trend from 2000-2014. Public schools started slightly stronger but quickly fell below 95% by 2006.
#
# The p-values for all three are very low which lends a good degree of confidence in the results that the difference between Public and Private schools is statistically significant. The question may be raised concerning the difference in the specific integer values and why they vary. It would appear that differences in the schedules of vaccines make the act of vaccinating more difficult. DTP rate had the lowest t-statistic because it has the one of the earliest possible vaccination rates at 0-2 months in California. The introduction of a new DTaP vaccine which also immunizes the mother during the pregnancy. This new vaccine was accompanied by a large amount of support from the government and hospitals to use the new vaccine.
#
# The Polio vaccine has a similar early possible vaccination date but without the option of a vaccine dose being administered during the pregnancy which may explain the slight difference between the two. Finally the MMR vaccine has the latest possible vaccination date of the three, starting at 12 months.

# %%
t1 = stats.ttest_ind(pub['MMR_rate'],priv['MMR_rate'])
t2 = stats.ttest_ind(pub['Polio_rate'],priv['Polio_rate'])
t3 = stats.ttest_ind(pub['DTP_rate'],priv['DTP_rate'])

t1, t2, t3
# Out:
# (Ttest_indResult(statistic=44.286742332696726, pvalue=0.0),
#  Ttest_indResult(statistic=36.83266060280501, pvalue=2.8412637617394944e-295),
#  Ttest_indResult(statistic=31.30516633402306, pvalue=3.1140669360467088e-214))

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 6))
fig.suptitle('Distribution of Vaccination rates for Kindergartners', fontsize=16)
axs[0].set_ylabel('number of instances')

axs[0].hist(SD['MMR_rate'], bins=20)
axs[0].set_xlabel('MMR Vaccination Rates');

axs[1].hist(SD['DTP_rate'], bins=20)
axs[1].set_xlabel('DTP Vaccination Rates');

axs[2].hist(SD['Polio_rate'], bins=20);
axs[2].set_xlabel('Polio Vaccination Rates');

# %% [markdown]
# ### Evaluation of H1 "We will see increased rates of non-vaccination that are below threshold immunity."
# $1-(1/R_0)$. is the formula that the CDC uses to calculate the threshold level of vaccination necessary in the population.
#
# $R_0$ is called the *Reproductive Number*. It is calculated empirically and is unique to every infectious agent. $R_0$ measures the number of infected cases that can arise from an initial infection. For most diseases like Measles (found in the MMR vaccine), $R_0 = 12$. Ideally for a distribution of vaccination rates, one would expect to see very low distributions everywhere except around 95%-100% In the histograms.
#
# The data we see above gives us a reason to suspect herd immunity is being compromised. Here we can clearly see that we do not have the distribution of vaccination rates we would want to see at the state level. There are classes with vaccination rates below 95% for all the 3 major vaccines that should be completed by the time a student enters Kindergarten. While there is cause for concern, this graph is not definitive. We should bear in mind that this data is collected only for Kindergarten students. It's possible that many of the students who weren't vaccinated at the time of registration, were vaccinated later in the year.
#
# ### Statistical Testing
# The t-tests below were computed with the following two groups; group A is Californian Kindergartners and group B is an ideal population with a mean of 95% vaccination rates, the threshold value set by the CDC. The t-statistics are all negative meaning that the average vaccination rate in Californias Kindergartners from 2000-2014 is lower than 95%.

# %%
t4=stats.ttest_1samp(SD['MMR_rate'],0.95)
t5=stats.ttest_1samp(SD['DTP_rate'],0.95)
t6=stats.ttest_1samp(SD['Polio_rate'],0.95)

t4, t5, t6
# Out:
# (Ttest_1sampResult(statistic=-60.729759142476624, pvalue=0.0),
#  Ttest_1sampResult(statistic=-63.9678246923629, pvalue=0.0),
#  Ttest_1sampResult(statistic=-55.32596431913939, pvalue=0.0))

# %% [markdown]
# ## H1 Methodology ('Private school will show a higher rate of Personal Belief Exemptions than Public schools.')
# To test the second hypothesis we separate the data based on the public private label in School Type. We will then make box plot for each label the data where each box plot will represent a year from 2000-2014. The first set of boxplots will make use of the raw counts of vaccinations
#
# The second set of boxplots will also be split by Private and Public but will make use of the calculated rates of vaccination instead of the raw counts.
#
# Public schools account for a much larger portion of the population (approximately 81,000 public schools to 28,000 Private schools) and also tend to have larger class sizes. The use of the Personal Belief rates instead of raw counts mitigates the class size bias just as it did for the vaccination rates as well.
#
# However we need to control for the bias towards the amount of Public schools vs Private schools. The best way to account for this bias is by underampling the Public School data

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x="year", y="n", hue="schoolType", style="schoolType", data=SD)
plt.title('Average class size in California', Fontsize=16);
plt.xlabel('Year', Fontsize=14);
plt.ylabel('Number of students', Fontsize=14);
plt.xlim(2000,2014);
plt.ylim(0,100);

# %%
SDpriv = SD.loc[lambda df:SD['schoolType'] == 'PRIVATE'] #new dataframe with only private schools
SDpub = SD.loc[lambda df:SD['schoolType'] == 'PUBLIC'] #new dataframe with only public schools

SDU = SDpub.sample(n=28005)#creating an undersampled dataframe from Public school data, without replacement.
frames = [SDU, SDpriv] #set a variable equal to my two dataframes 
SDsampled = pd.concat(frames) #merge both dataframes together for a full undersampled DF


x1= SDsampled['year']
y1= SDsampled['nPBE']

x2= SDpriv['year']
y2= SDpriv['nPBE']
#defining variables for my plots

plt.figure(figsize=(15,8)) #subplot for my two boxplots
plt.subplot(1, 2, 1)
ax = sns.boxplot(x=x2, y=y2, data=SDpriv).set_title('Distribution of Personal Belief Exemptions in private schools');
plt.yscale("log");
plt.xticks(rotation=45);

plt.subplot(1,2,2)
ax = sns.boxplot(x=x1, y=y1, data=SDsampled).set_title('Distribution of Personal Belief Exemptions in public schools');
plt.yscale("log");
plt.xticks(rotation=45);

# %%
#note that for my two groups in this t-test I will use a=y1 and b=y2 as defined above since they refer to the two experimental groups

t8 = stats.ttest_ind(y1,y2)
t8
# Out:
# Ttest_indResult(statistic=14.652482918946417, pvalue=1.484563808567343e-48)

# %%
x1= SDsampled['year']
y3= SDsampled['PBE_rate']

x2= SDpriv['year']
y4= SDpriv['PBE_rate']

plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
ax = sns.boxplot(x=x2, y=y4, data=SDpriv).set_title('Distribution of PBE rate in private schools')
plt.xticks(rotation=45);
plt.subplot(1,2,2)
ax = sns.boxplot(x=x1, y=y3, data=SDsampled).set_title('Distribution of PPBE rate in public schools')
plt.xticks(rotation=45);

# %%
t9 = stats.ttest_ind(y3,y4)
t9
# Out:
# Ttest_indResult(statistic=-9.034902863624339, pvalue=1.6740253664960466e-19)

# %% [markdown]
# ### First pair of box plots
# The first pair of boxplots show the distribution of Personal Belief Exemptions (abbreviated PBE) for the years 2000-2014. The two box plots represent private and public schools across California. A log scale was used in these graphs because of the presence of so many outliers. The first things we can note is the difference in scale between the number of exemptions reported in public and private schools overall. Public schools have reported exemptions in the hundreds while private schools didn't report any numbers in that range.
#
# It should be noted that since Public schools account for a larger portion of schools in this data set (approximately 81,000 to 28,000) and in California overall. It can be argued that since Public schools have a larger share of the student body then we would expect to see them report more exemptions.
#
# Private schools show a steady amount of Exemptions 2004-2012 when there is a sudden increase in the size of the box and a sudden increase in the upper extreme value of the box as well. Public schools by contrast began showing an increase in the amount of exemptions in the year 2008, much earlier than private schools. One thing to note is that in these graphs, Public schools after 2010 are the only ones where the median value is shown on the graph despite the log scale. This is mainly due to the large number of outliers that are also in the $10^2$ range
#
# This graph is not conclusive about which segment of the school population is contributing more to higher exemption rates. Based on this graph we can say the Public schools reported more and showed a larger increase in the amount of exemptions.
#
#
# ### Second Pair
# The second pair of boxplot point towards Private schools as being more culpable. The difference between the two sets of boxplots is that the second set used the rates of exemptions per class instead of the integer value. This method takes into account the earlier observation that class sizes were larger in public schools which may bias the data. Using this method builds on our earlier lineplots as well. In addition to Private schools showing lower vaccination rates than Public schools overall, they also are reporting higher trends in their Personal Belief Exemption rates. This is a conerning conclusion to reach because there is a two-fold effect that is appearing more strongly in Private schools than in Public schools
#
# ### Statistical testing
# The t statistic for the first pair of box plots has two groups y1 (undersampled public schools) and y2(private schools). The result were "tstatistic=14.652482918946417, pvalue=1.484563808567343e-48". This confirms that the public schools had a higher rate of Persoal Belief exemptions. The low p-value lends a good deal of confidence to this result
#
# The second pair was a bit different as discussed above. It used a calculated rate instead of the raw counts to account for the larger class sizes. The results here were slightly more illuminating. The results had two groups y3 and y4. The order of the groups was the same and the results were the following "tstatistic=-9.034902863624339, pvalue=1.6740253664960466e-19)". When using the rates instead of raw counts we obtained a result that justifies our reasoning in accounting for different class sizes. The negative value of the t-statistic shows that the the RATE of exemptions in public school was lower than the the rate in Private schools. A similarly low p-value makes this conclusion confident. Private schools, when accounting for class sizes, have higher rates of personal exemptions not rooted in amedical reason.

# %% [markdown]
# ## H1, "Economic class is a factor and families with higher incomes will also show a higher rate of non-vaccination."
#
# ### Methodology
# Using information from the [U.S. Census Bureu](https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?src=CF), I was able to compare the median houshold income by county. This was my primary method of judging the wealth of a county. The Census Bureu requires you to input certain constraints before aggregating the data. This information was obtained by typing California into the community search, clicking under Income in the side tab and choosing median income from the choices. Once here I used the information from  2014, the last year my vaccination data was reported. Since my vaccination data doesn't include income data per student, this is the closest I can come to testing this hypothesis. The counties to be compared are Mendocino (median Houshold Income = $\$$43,290), Marin (median Houshold Income = $\$$ 91,529), Siskiyou (median Houshold Income = $\$$ 37,495) and Sonoma (median Houshold Income = $\$$ 63,799).
#
# The counties I picked also appeared in the list with the largest 50 rates of Personal Belief Exemptions in California.

# %%
MAR = SD.loc[lambda df:SD['COUNTY'] == 'MARIN'] #new dataframe for Marin County
MEN = SD.loc[lambda df:SD['COUNTY'] == 'MENDOCINO'] #Mendocino County
SM = SD.loc[lambda df:SD['COUNTY'] == 'SONOMA'] #Sonoma County
SK = SD.loc[lambda df:SD['COUNTY'] == 'SISKIYOU'] #Siskiyou County

fig, axs = plt.subplots(1, 4, figsize=(20, 6))
fig.suptitle('Distribution of Vaccination rates across counties', fontsize=18)
axs[0].set_ylabel('number of instances')

axs[2].hist(MEN['MMR_rate'], bins=20)
axs[2].set_xlabel('MMR Vaccination Rates in Mendocino', fontsize=13);

axs[0].hist(MAR['MMR_rate'], bins=20)
axs[0].set_xlabel('MMR Vaccination Rates in Marin', fontsize=13);

axs[1].hist(SM['MMR_rate'], bins=20);
axs[1].set_xlabel('MMR Vaccination Rates in Sonoma', fontsize=13);

axs[3].hist(SK['MMR_rate'], bins=20);
axs[3].set_xlabel('MMR Vaccination Rates in Siskiyou', fontsize=13);

# %%
tval = stats.ttest_ind(MAR['MMR_rate'],MEN['MMR_rate'])
tval1 = stats.ttest_ind(MAR['MMR_rate'],SM['MMR_rate'])
tval2 = stats.ttest_ind(MAR['MMR_rate'],SK['MMR_rate'])

tval, tval1, tval2
# Out:
# (Ttest_indResult(statistic=2.9258384489415525, pvalue=0.003495046686846358),
#  Ttest_indResult(statistic=-5.2317603426966, pvalue=1.803724815716246e-07),
#  Ttest_indResult(statistic=3.5044958808030744, pvalue=0.0004745424070769475))

# %%
tval3 = stats.ttest_ind(MAR['DTP_rate'],MEN['DTP_rate'])
tval4 = stats.ttest_ind(MAR['DTP_rate'],SM['DTP_rate'])
tval5 = stats.ttest_ind(MAR['DTP_rate'],SK['DTP_rate'] )

tval3, tval4, tval5
# Out:
# (Ttest_indResult(statistic=3.1883232045508336, pvalue=0.001465172001150077),
#  Ttest_indResult(statistic=-4.421449407003046, pvalue=1.0179558988459294e-05),
#  Ttest_indResult(statistic=4.079153488962219, pvalue=4.822119846031108e-05))

# %%
tval7 = stats.ttest_ind(MAR['Polio_rate'],MEN['Polio_rate'])
tval8 = stats.ttest_ind(MAR['Polio_rate'],SM['Polio_rate'])
tval9 = stats.ttest_ind(MAR['Polio_rate'],SK['Polio_rate'])

tval7, tval8, tval9
# Out:
# (Ttest_indResult(statistic=3.282231723501626, pvalue=0.0010572879590884108),
#  Ttest_indResult(statistic=-4.582390308294464, pvalue=4.799242063304127e-06),
#  Ttest_indResult(statistic=3.7647944546086545, pvalue=0.00017485767759886577))

# %%
tval10 = stats.ttest_ind(SM['Polio_rate'],MEN['Polio_rate'])
tval11 = stats.ttest_ind(SM['Polio_rate'],SK['Polio_rate'])


tval10, tval11
# Out:
# (Ttest_indResult(statistic=6.659759209111448, pvalue=3.4799246100816815e-11),
#  Ttest_indResult(statistic=6.667901895801704, pvalue=3.3398477212198415e-11))

# %% [markdown]
# ### Statistical Testing
# The four counties used for this comparison have very different median incomes and are graphed from left to right, greatest to least. Only the MMR Vaccination rates are shown because the distributions for the other vaccines are very similar and do not differ significantly.
# It should be noted that these vaccination rates are very different from the histograms we saw for all of California. When we looked at the aggregated data for California, we couldn't see the details of the smaller segments of the population. As noted earlier, human populations are not homogenous and different communities behave and live under slightly different conditions. This natural variation was hidden in the aggregated data.
# If the state data was less than ideal, then these are cause for concern. Vaccination rates as low as 60% are found on this graph. These counties also have populations that are below 500,000, that is to say their herds are much smaller. There doesn't seem to be any evidence of a link between the wealth of a county and it's vaccination rates. In fact the opposite is true. Siskiyou County which is among the poorest in the State has some of the lowest vaccination rates in kindergarteners.
#
# In the first set of t-tests I used Marin County as our benchmark county and as group A throughout. It is also the wealthiest in terms of Median Household income of the group. The first t-test compared Marin County to Mendocino and Marin County performed better in the sense that the t-statistic was positive. The t-statistic was also positive for Marin county compared to Sisikyou County which was also much poorer than Marin in terms of median household income. This seems to suggest that income plays a positive role as opposed to a negative one. However when we compare Marin county to Sonoma County which has a median income of approximately 63,000 (still far below the 90000 of Marin County), the t-statistic is negative and the p-value is similarly low to the other t-statistics calculated lending credence to the idea.
#
# A repeat of the t-tests with the DTP vaccination rates and Polio rates showed the same pattern. Explaining this is difficult.It seems that low income counties have lower vaccination rates than higher income counties such as Sonoma and Marin. Tval10 and tval11 above show a t-test between Sonoma and Mendocino and Sisikyou respectively. These t-scores show that Sonoma's higher vaccination rate is significantly bigger. However, when we compare these high income counties to each other, median household income doesn't have the same effect the higher you go(Marin had negative t-values for every vaccine compared to Sonoma). While access to medical care in low income counties is a likely culprit for lower vaccination rates, Counties uch as Marin have much better access and families that can afford specialized healthcare which shows that higher income counties at the wealthier end do have lower vaccination rates but only when compared to middle class families and not those making below $50,000 a year.
